# %% [markdown]
# <a href="https://colab.research.google.com/github/swetha315245/Python-Code/blob/main/python_sir.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
first_name = "sathya"
last_name = "technolagy"
print(first_name,last_name)
# Out:
# sathya technolagy

# %%
a = 5
b = 7
c = a+b
print(c)
# Out:
# 12

# %%
a = 5.6
b = 10.5
c = a+b
print(c)
# Out:
# 16.1

# %%
a = 20
b = 2.5
c = a-b
print(c)
# Out:
# 17.5

# %%
mr_vishnu_annual_salary = 650000
no_of_months = 12
print(mr_vishnu_annual_salary/no_of_months)
# Out:
# 54166.666666666664

# %%
m_salary = 345.60
year_days = 365
print(m_salary*year_days)
# Out:
# 126144.00000000001

# %%
pcost = 345.60
orders = 3
charges = 20
tip = 30
bill_amount = (pcost*orders)
print(bill_amount)
print(bill_amount+charges+tip)
# Out:
# 1036.8000000000002
# 1086.8000000000002

# %%
s1 = 92
s2 = 98
s3 = 99
print(s1+s2+s3)
no_sub = 3
print(s1+s2+s3/no_sub)
# Out:
# 289
# 223.0
