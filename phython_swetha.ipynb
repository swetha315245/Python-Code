# %% [markdown]
# <a href="https://colab.research.google.com/github/swetha315245/Python-Code/blob/main/phython_swetha.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# friday
#
# 5 - 12 -2025
#
# veriable
#
#
# 1.   the name given to memory location
# 2.   veriable are used to store values
#
#
#
# ---

# %%
age = 22                        # age     = veriable
print ("age :", age)            # 22      = value
                                # '='     = operator
                                # print() = function
# Out:
# age : 22

# %%
#a = 5
#b = a                       # ERROR because we don't have "p" veriable
#c = p
#print (c)

# %%
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3184303369.py in <cell line: 0>()
# ----> 1 print(a)
#
# NameError: name 'a' is not defined

# %% [markdown]
# NOTE :
#        " in one veriable we can store only one value at a time,
#         whenever secound value comes then first value is deleted."

# %%
# example
a = 8
a = 26
print("A :",a)
# Out:
# A : 26

# %%
priya = 25
priya = 28
print("priya :",priya)
# Out:
# priya : 28

# %% [markdown]
# NOTE :
#         " we can  use more then one veriable and values at a time"
#         syntax :
#                 veriable_1,veriable_2 = value 1 ,value 2
#
#          rule : no of veriables and values should me match

# %%
a,b = 2,5
print("A :",a)
print("B :",b)
# Out:
# A : 2
# B : 5

# %%
#a,b,c = 2,5,
#print("a is :",a)
#print("b is :",b)
#print("c is :",c)

# %% [markdown]
# SATURDAY
#
# PROGRAMS
#
# 6 / 12 /2025

# %% [markdown]
# 1. consider first name as "sathya" and last name as "technology"now print fullname

# %%
fname = 'sathya'
lname = "technology"
print("fullname as :",fname + lname)
# Out:
# fullname as : sathyatechnology

# %% [markdown]
# 2. consider a value as 5 and b value as 7 now add a,b store into c,then display c

# %%
a = 5
b = 7
c = a+b
print("c :",c)
# Out:
# c : 12

# %% [markdown]
# 3. wrrite a program take a=5.6, b=10.5 and display sum

# %%
a = 5.6
b = 10.5
c = a + b
print("sum :",c)
# Out:
# sum : 16.1

# %%
a = 20
b = 2.5
c = a-b
print("subtraction :",c)
# Out:
# subtraction : 17.5

# %%
asal    = 650000
msalary = asal/12
print("mr.vishnu monthly salary :",msalary)
# Out:
# mr.vishnu monthly salary : 54166.666666666664

# %%
msal = 34500.0
asal = msal*12
print("mr.avinash annual salary :",asal)
# Out:
# mr.avinash annual salary : 414000.0

# %%
pcost    = 345.60
order    = 3
scharges = 20
tip      = 30
bill_amt = pcost*order
total_amt = bill_amt + scharges + tip
print("bill amount :",bill_amt)
print("total bill amount :",total_amt)
# Out:
# bill amount : 1036.8000000000002
# total bill amount : 1086.8000000000002

# %%
s1  = 92
s2  = 98
s3  = 99
tm  = s1+s2+s3
avg = tm/3
print("average marks :",avg)
# Out:
# average marks : 96.33333333333333

# %% [markdown]
# avg = total marks / no of subjects

# %%
celsius = 32
fahrenheit = (celsius * 9/5) + 32
print("fahrenheit :",fahrenheit)
# Out:
# fahrenheit : 89.6

# %% [markdown]
# fahrenheit formula = celsius * 9/5 + 32

# %%
fahrenheit = 102
celsius = (fahrenheit*5/9)-32
print("celsius :",celsius)
# Out:
# celsius : 24.666666666666664

# %% [markdown]
# celsiusn formula = fahrenheit * 5/9 -32

# %%
BD_amt = 500000
years  = 5
rate   = 7.8
SI = (BD_amt*years*rate)/100
famt = BD_amt + SI
print("interest amount :",SI)
print("mr.venkat received amount :",famt)
# Out:
# interest amount : 195000.0
# mr.venkat received amount : 695000.0

# %% [markdown]
# simple interest formula :
#
# P = Principal amount
#
# R = Rate of interest (as a percentage)
#
# T = Time period (in years)
#
#   **SI**= PTR/100

# %% [markdown]
# swapping : interchange values is called swapping.

# %% [markdown]
# by using 3rd veriable

# %%
a = 2
b = 3
c = a
a = b
b = c
print("a :",a)
print("b :",b)
# Out:
# a : 3
# b : 2

# %% [markdown]
# without using 3rd veriable

# %%
a = 1
b = 2
a = a+b
b = a-b
a = a-b
print("a :",a)
print("b :",b)
# Out:
# a : 2
# b : 1

# %% [markdown]
# without using 3rd veriable and +,- operators

# %%
a,b = 2,3
b,a = a,b
print("a :",a)
print("b :",b)
# Out:
# a : 3
# b : 2

# %% [markdown]
# 7 / 12 / 2025  sunday

# %%
sread = 11236
rread = 11494
km = (rread-sread)
print("pooja travelled kilometers :",km)
# Out:
# pooja travelled kilometers : 258

# %%
mcost = 220
bcost = 360
mord = 3
bord = 2
tip = 20
mbill = mcost * mord
bbill = bcost * bord
tbill = mbill + bbill + tip
shbill = tbill/3
print ("sharing bill :",shbill)
# Out:
# sharing bill : 466.6666666666667

# %%
MMbill = 930.0
mday   = 31
leavs  = 4
perdc  = MMbill/mday
tdays  = mday - leavs
mmbill_amt = tdays * perdc
print("march month milk bill :",mmbill_amt)
# Out:
# march month milk bill : 810.0

# %% [markdown]
# cost per day formula :
#
#       total bill/ days in march
# delivery days :
#
#        days in march - leavs
#
# bill Amount :
#
#        delivery days * cost per day

# %%
aday   = 94
totald = 126
atendp = aday/totald*100
print("attendance percentage :",atendp)
# Out:
# attendance percentage : 74.60317460317461

# %% [markdown]
#  percentage formula :
#
#           (Part / Whole)* 100

# %%
wtins = 6
wcost = 20
AMD = 30
TWC = wtins * wcost * AMD
print("august month water bill :",TWC)
# Out:
# august month water bill : 3600

# %%
_1lpc = 108.96
tpc   = 300
qnty = tpc/_1lpc
print("quantity :",qnty)
# Out:
# quantity : 2.7533039647577096

# %%
soldb = 1680
mngb  = 1150
profit = soldb - mngb
print("profit :",profit)
# Out:
# profit : 530

# %%
pcost = 200
gst = 20
gstA = pcost * gst/100
fcost = pcost - gstA
print("gst amount :",gstA)
print("final cost :",fcost)
# Out:
# gst amount : 40.0
# final cost : 160.0

# %%
pcost = 326.50
cord  = 3
dis   = 20
billA = pcost * cord
disA  = billA * dis/100
fcost = billA - disA
print("bill amount :",billA)
print("discount amount :",disA)
print("final cost :",fcost)
#
# Out:
# bill amount : 979.5
# discount amount : 195.9
# final cost : 783.6

# %%
EMS = 30000
pf  = 12
tax = 8
pfA = EMS * pf/100
taxA = EMS * tax/100
FMS = EMS - pfA - taxA
print("pf amount :",pfA)
print("tax amount :",taxA)
print("final monthly salary :",FMS)
# Out:
# pf amount : 3600.0
# tax amount : 2400.0
# final monthly salary : 24000.0

# %%
bank  = 500000
years = 4
rate  = 11.4
si  = (bank*years*rate)/100
famt = bank + si
emi  = famt/12
print("interest amount :",si)
print("final amount :",famt)
print("monthly emi :",emi)
# Out:
# interest amount : 228000.0
# final amount : 728000.0
# monthly emi : 60666.666666666664

# %% [markdown]
# simple interest formula :
#
#        P = Principal amount
#
#        R = Rate of interest (as a percentage)
#
#        T = Time period (in years)
#
#        **SI**= PTR/100
#
# final amount :
#
#     principal amount + si
#
# emi :
#
#     final amount / 12

# %%
CMR = 2456
LMR = 2234
cpu = 3.46
tax = 0.06
schrg = 30

units = CMR - LMR
cou   = units * cpu
taxAn = cou  * tax
total = cou + taxA + schrg

print("units consumed :",units)
print("cost of units :",cou)
print("tax amount :",taxA)
print("total bill :",total)
# Out:
# units consumed : 222
# cost of units : 768.12
# tax amount : 2400.0
# total bill : 3198.12

# %% [markdown]
# units consumed :
#
#     current reading - last reading
#
# cost of units consumed :
#
#     units consumed * cost per unit
#
# tax amount :
#
#     units consumed * tax per unit
#
# total bill :
#
#     cost of units + tax amount + service charges

# %%
CRR = 11494
CSR = 11236
kmc = 15
tolc = 200
NOKM = CRR - CSR
billA = NOKM * kmc + tolc
print("no of kilometers :",NOKM)
print("pooja bill amount :",billA)
# Out:
# no of kilometers : 258
# pooja bill amount : 4070

# %% [markdown]
# 8 / 12 /2025
#
# monday
#
# by using input function

# %%
emp_id   = input("enter employee id : ")
emp_name = input("enter employee name : ")
gender   = input("enter employee gender : ")
emp_sal  = float(input("enter employee salary : "))
moths    = int(input("enter month : "))
AS       = emp_sal * 12
print()
print("employee id :",emp_id)
print("employee name :",emp_name)
print("employee gender :",gender)
print("employee salary :",emp_sal)
print("annual salary",AS)
# Out:
# enter employee id : 2115455
# enter employee name : swetha
# enter employee gender : female
# enter employee salary : 30000
# enter month : 12
#
# employee id : 2115455
# employee name : swetha
# employee gender : female
# employee salary : 30000.0
# annual salary 360000.0

# %%
bcost = 395.25
qty   = int(input("enter quantity : "))
billA = bcost * qty
print("bill amount :",billA)
# Out:
# enter quantity : 3
# bill amount : 1185.75

# %%
amt  = eval(input("enter amount :"))
dc   = eval(input("enter doller cost :"))
doll = amt/dc
print("amount in dollers :",doll)
# Out:
# enter amount :256
# enter doller cost :90.14
# amount in dollers : 2.8400266252496116

# %%
doll   = eval(input("enter doller coost :"))
amt    = eval (input("enter amount :"))
rupees = doll * amt
print("doller to rupees :",rupees)
# Out:
# enter doller coost :90.14
# enter amount :3000
# doller to rupees : 270420.0

# %%
gtc      = 460
inc_cost = 50
actual   = gtc + inc_cost/100
NOT      = int(input("enter no of tickets :"))
TBA      = actual * NOT
print("general ticket cost :",gtc)
print("increased cost :",inc_cost)
print("total bill amount :",TBA)
# Out:
# enter no of tickets :6
# general ticket cost : 460
# increased cost : 50
# total bill amount : 2763.0

# %%
EAS   = eval(input("enter employee annual salary :"))
hike  = int(input("hike percentage :"))
ahike = EAS *hike/100 + EAS
NMS   = ahike/12
print("employee annual salary :",EAS)
print("hike percentage :",hike)
print("after hike salary :",ahike)
print("new monthly salary :",NMS)
# Out:
# enter employee annual salary :300000
# hike percentage :6
# employee annual salary : 300000
# hike percentage : 6
# after hike salary : 318000.0
# new monthly salary : 26500.0

# %%
MVL = eval(input("enter market value land :"))
OSD = 5
NSD = 7
OSDA = MVL - MVL * OSD/100
NSDA = MVL - MVL * NSD/100
diff = OSDA - NSDA
print("market value land :",MVL)
print("old stam duty :",OSD)
print("new stam duty  :",NSD)
print("old stam duty amount :",OSDA)
print("new stam duty amount :",NSDA)
print("difference :",diff)
# Out:
# enter market value land :30000000
# market value land : 30000000
# old stam duty : 5
# new stam duty  : 7
# old stam duty amount : 28500000.0
# new stam duty amount : 27900000.0
# difference : 600000.0

# %%
celsius = eval(input("enter celsius : "))
fahrenheit = (celsius * 9/5) + 32
print("fahrenheit :",fahrenheit)
# Out:
# enter celsius : 56
# fahrenheit : 132.8

# %%
f = eval(input("enter fahrenheit : "))
c = f *5/9 - 32
print("celsius :",c)
# Out:
# enter fahrenheit : 65
# celsius : 4.111111111111114

# %%
mc = eval(input("mango cost per kg :"))
qty = eval(input("quantity :"))
dis = 22
BA  = mc * qty
DA  = BA * dis/100
TBA = BA - DA
print("bill amount :",BA)

print("discount amount :",DA)
print("total bill amount :",TBA)
# Out:
# mango cost per kg :90
# quantity :3
# bill amount : 270
# discount amount : 59.4
# total bill amount : 210.6

# %%
GTC = 3450
GST = 18
ITC = 3200
IGST = 12
GTCA = GTC + GTC * GST/100
ITCA = ITC + ITC * IGST/100
SA = GTCA - ITCA
print("general ticket cosT amount :",GTCA)
print("income tax amount :",ITCA)
print("mr. venkat saved amount :",SA)
# Out:
# general ticket cosT amount : 4071.0
# income tax amount : 3584.0
# mr. venkat saved amount : 487.0

# %%
km = eval(input("enter kilometers :"))
meters = km * 1000
print("convert into km to meters :",meters)
# Out:
# enter kilometers :6
# convert into km to meters : 6000

# %%
hours = eval(input("enter hours :"))
days  = hours/24
print("converted into hours to days :",days)
# Out:
# enter hours :68
# converted into hours to days : 2.8333333333333335

# %% [markdown]
# functoins

# %%
def show():
  print("hi")
def display():
  print("hello")
print("thank you")
# Out:
# thank you

# %%
def show():
  print("hai")
def display():
  print("hello")
show()
print("thank you")
# Out:
# hai
# thank you

# %%
def show():
  print("hai")
def display():
  print("hello")
display()
print("thank you")
# Out:
# hello
# thank you

# %%
def show():
  print("hai")
def display():
  print("hello")
show()
display()
print("thank you")
# Out:
# hai
# hello
# thank you

# %%
def show():
  print("hai")
def display():
  print("hello")
  show()
print("thank you")
# Out:
# thank you

# %%
def show():
  print("hai")
def display():
  print("hello")
  show()
show()
print("thankyou")
# Out:
# hai
# thankyou

# %%
def show():
  print("hai")
  display()
def display():
  print("hello")
display()
print("thank you")
# Out:
# hello
# thank you

# %%
def show():
  print("hai")
  display()
def display():                 # display is not defined why because first we declare callfunction after that we call function.
  print("hello")
  show()
display()
show()
print("thank you")
# Out:
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# hello
# hai
# ...

# %%
def show():
  print("hai")
def display():
  print("hello")
  display()
display()
print("thank you")
# Out:
#   File "/tmp/ipython-input-3659797509.py", line 5
#     display()
#     ^
# IndentationError: unexpected indent

# %%
def show():
  print("hai")
  show()
def display():
  print("hello")
  display()
show()
display()
print("thank you")
# Out:
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# hai
# ...

# %% [markdown]
# functional programs 11/12/2025

# %%
def msal(annualsal):
  msal = annualsal / 12
  print("monthly salary :",msal)
msal(500000.0)
# Out:
# monthly salary : 41666.666666666664

# %%
def Asal(monthlysal):
  Asal = monthlysal * 12
  print("annual salary :",Asal)
Asal(50000.0)
# Out:
# annual salary : 600000.0

# %%
def totalM(s1,s2,s3):
  totalM = s1+s2+s3
  print("total marks :",totalM)
totalM(99,86,92)
# Out:
# total marks : 277

# %%
def RS(dol,dcost):
  RS = dol*dcost
  print("amount in rupees",RS)
RS(985,90.14)
# Out:
# amount in rupees 88787.9

# %%
def intA(landAmt,duration,roi):
  intA = landAmt * duration * roi/100
  print("interest AAmount :",intA)
intA(2000000,5,3)
# Out:
# interest AAmount : 300000.0

# %%
def FA(loanAmt,intamt):
  FA = loanAmt + intamt
  print("final amount :",FA)
FA(100000,20000)
# Out:
# final amount : 120000

# %%
def EMI(finalA,dur):
   EMI = finalA/dur
   print("monthly EMI :",EMI)
EMI(300000,12)
# Out:
# monthly EMI : 25000.0

# %%
def AttedP(wdays,Pdays):
  AttendP = Pdays/wdays*100
  print("attendance percentage :",AttendP)
AttedP(265,235)
# Out:
# attendance percentage : 88.67924528301887

# %%
def disA(pcost,disP):
  disA = pcost - pcost * disP/100
  print("discount amount :",disA)
disA(3000.0,25)
# Out:
# discount amount : 2250.0

# %%
def GSTA(tvcost,gstp):
  GSTA = tvcost * gstp/100 + tvcost
  print("GST amount :",GSTA)
GSTA(40000.0,8)
# Out:
# GST amount : 43200.0
