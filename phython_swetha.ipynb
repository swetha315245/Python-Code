# %% [markdown]
# <a href="https://colab.research.google.com/github/swetha315245/Python-Code/blob/main/phython_swetha.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 5 - 12 -2025
#
# veriable
#
#
# 1.   the name given to memory location
# 2.   veriable are used to store values
#
#
#
# ---

# %%
age = 22                        # age     = veriable
print ("age :", age)            # 22      = value
                                # '='     = operator
                                # print() = function
# Out:
# age : 22

# %%
a = 5
b = a                       # ERROR because we don't have "p" veriable
c = p
print (c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4206261181.py in <cell line: 0>()
#       1 a = 5
#       2 b = a                       # ERROR because we don't have "p" veriable
# ----> 3 c = p
#       4 print (c)
#
# NameError: name 'p' is not defined

# %%
print(a)
# Out:
# 26

# %% [markdown]
# NOTE :
#        " in one veriable we can store only one value at a time,
#         whenever secound value comes then first value is deleted."

# %%
# example
a = 8
a = 26
print("A :",a)
# Out:
# A : 26

# %%
priya = 25
priya = 28
print("priya :",priya)
# Out:
# priya : 28

# %% [markdown]
# NOTE :
#         " we can  use more then one veriable and values at a time"
#         syntax :
#                 veriable_1,veriable_2 = value 1 ,value 2
#
#          rule : no of veriables and values should me match

# %%
a,b = 2,5
print("A :",a)
print("B :",b)
# Out:
# A : 2
# B : 5

# %%
#a,b,c = 2,5,
#print("a is :",a)
#print("b is :",b)
#print("c is :",c) ERROR IS COMMING WHY BECAUSE  NO VALUES IN "C"

# %% [markdown]
# CONSIDER FIRSTNAME AS "SATHYA" LASTNAME AS TECHNOLOGY NOW FIND OUT FULLNAME

# %%
first_name = "sathya"
last_name = "technology"
full_name = first_name+last_name
print("full_name :",full_name)
# Out:
# full_name : sathyatechnology

# %% [markdown]
# consider A value is 7 and B value is 2.6 now  find out sum.

# %%
a = 7
b = 2.6
c = a+b
print("sum is :",c)
# Out:
# sum is : 9.6

# %% [markdown]
# consider onion cost 60rs per kg customer purchesed for 5kg now find out bill amount.

# %%
onion_cost = 60
customer = 5
bill_amount = onion_cost * customer
print("bill amount :",bill_amount)
# Out:
# bill amount : 300

# %% [markdown]
# consider jeanscost is 1500.0, shop provides 20% discount. now find out discount amount and final cost

# %%
jcost    = 1500
discount = 20
discount_amt = jcost*discount/100
final_cost = jcost-discount_amt
print("discount amount :",discount_amt)
print("final cost :",final_cost)
# Out:
# discount amount : 300.0
# final cost : 1200.0
